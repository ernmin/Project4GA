# %%
import sqlite3
import pandas as pd
import json

# %%
with open('../EDA/user_course_info_cleaned.json', 'r') as file:
    user_course_info = json.load(file)

df_user_course_info = pd.DataFrame(user_course_info)

# %%
with open('../EDA/teacher_stats_cleaned.json', 'r') as file:
    teacher_stats = json.load(file)

df_teacher_stats = pd.DataFrame(teacher_stats)

# %%
with open('../EDA/pro_course_cleaned.json', 'r') as file:
    pro_course = json.load(file)

df_pro_course = pd.DataFrame(pro_course)

# %%
with open('../EDA/price_list_cleaned.json', 'r') as file:
    price_list = json.load(file)

df_price_list = pd.DataFrame(price_list)

# %%
with open('../EDA/also_speaks_cleaned.json', 'r') as file:
    also_speaks = json.load(file)

df_also_speaks = pd.DataFrame(also_speaks)

# %%
with open('../EDA/also_speaks_reference.json', 'r') as file:
    also_speaks_reference = json.load(file)

df_also_speaks_reference = pd.DataFrame(also_speaks_reference)

# %%
df_user_course_info
# Out:
#         user_id           nickname  is_tutor  is_pro origin_country_id  \
# 0         55502         Micky Mick         1       0                CN
# 1        113638                Xin         1       1                CN
# 2        114708  Amy (Féng lǎoshī）         0       1                CN
# 3        132815           Julie 줄리         1       0                KR
# 4        148092         Jhon Jairo         0       1                CO
# ...         ...                ...       ...     ...               ...
# 10465  32167939            Andrele         1       0                CA
# 10466  32168520         Daphne👩🏫🌸💗         1       0                PH
# 10467  32169200  Davide Castellani         1       0                IT
# 10468  32169731      FelixRansford         1       0                GB
# 10469  32171759      Roselene Noel         1       0                HT
#
#       living_country_id origin_city_id origin_city_name living_city_id  \
# 0                    CN        CN00226           Fushun        CN00006
# 1                    CA                                        CA00006
# 2                    CN        CN00201            Jilin        CN00201
# 3                    KR        KR00001            Seoul        KR00001
# 4                    CO        CO00101          Armenia        CO00006
# ...                 ...            ...              ...            ...
# 10465                CA        CA00000            Other        CA00000
# 10466                PH        PH00141           Baguio        PH00000
# 10467                IT        IT00000            Other        IT00000
# 10468                ES        GB00281           Exeter        ES00131
# 10469                DO        HT00000            Other        DO00000
#
#            living_city_name               timezone  trial_length  has_trial  \
# 0                   Beijing          Asia/Shanghai             2          0
# 1                  Montreal        America/Toronto             2          0
# 2                     Jilin          Asia/Shanghai             2          0
# 3                     Seoul             Asia/Seoul             2          0
# 4                  Medellin         America/Bogota             2          0
# ...                     ...                    ...           ...        ...
# 10465                 Other        America/Toronto             2          0
# 10466                 Other            Asia/Manila             3          0
# 10467                 Other            Europe/Rome             4          0
# 10468  Jerez de la Frontera          Europe/Madrid             2          0
# 10469                 Other  America/Santo_Domingo             2          0
#
#        trial_price  min_price  trial_session_count  has_beginner_course
# 0             1000       2000                   97                    1
# 1              999       2500                  227                    0
# 2              500       1990                    6                    1
# 3              750       1500                    0                    1
# 4             1000       2500                  182                    0
# ...            ...        ...                  ...                  ...
# 10465         1000       2000                    3                    1
# 10466          500        700                    0                    0
# 10467         1400       1400                    0                    1
# 10468          600       1400                    0                    0
# 10469          500       1200                    0                    0
#
# [10470 rows x 17 columns]

# %%
df_user_course_info.set_index('user_id', inplace=True)

# %%
df_user_course_info
# Out:
#                    nickname  is_tutor  is_pro origin_country_id  \
# user_id
# 55502            Micky Mick         1       0                CN
# 113638                  Xin         1       1                CN
# 114708    Amy (Féng lǎoshī）         0       1                CN
# 132815             Julie 줄리         1       0                KR
# 148092           Jhon Jairo         0       1                CO
# ...                     ...       ...     ...               ...
# 32167939            Andrele         1       0                CA
# 32168520         Daphne👩🏫🌸💗         1       0                PH
# 32169200  Davide Castellani         1       0                IT
# 32169731      FelixRansford         1       0                GB
# 32171759      Roselene Noel         1       0                HT
#
#          living_country_id origin_city_id origin_city_name living_city_id  \
# user_id
# 55502                   CN        CN00226           Fushun        CN00006
# 113638                  CA                                        CA00006
# 114708                  CN        CN00201            Jilin        CN00201
# 132815                  KR        KR00001            Seoul        KR00001
# 148092                  CO        CO00101          Armenia        CO00006
# ...                    ...            ...              ...            ...
# 32167939                CA        CA00000            Other        CA00000
# 32168520                PH        PH00141           Baguio        PH00000
# 32169200                IT        IT00000            Other        IT00000
# 32169731                ES        GB00281           Exeter        ES00131
# 32171759                DO        HT00000            Other        DO00000
#
#               living_city_name               timezone  trial_length  \
# user_id
# 55502                  Beijing          Asia/Shanghai             2
# 113638                Montreal        America/Toronto             2
# 114708                   Jilin          Asia/Shanghai             2
# 132815                   Seoul             Asia/Seoul             2
# 148092                Medellin         America/Bogota             2
# ...                        ...                    ...           ...
# 32167939                 Other        America/Toronto             2
# 32168520                 Other            Asia/Manila             3
# 32169200                 Other            Europe/Rome             4
# 32169731  Jerez de la Frontera          Europe/Madrid             2
# 32171759                 Other  America/Santo_Domingo             2
#
#           has_trial  trial_price  min_price  trial_session_count  \
# user_id
# 55502             0         1000       2000                   97
# 113638            0          999       2500                  227
# 114708            0          500       1990                    6
# 132815            0          750       1500                    0
# 148092            0         1000       2500                  182
# ...             ...          ...        ...                  ...
# 32167939          0         1000       2000                    3
# 32168520          0          500        700                    0
# 32169200          0         1400       1400                    0
# 32169731          0          600       1400                    0
# 32171759          0          500       1200                    0
#
#           has_beginner_course
# user_id
# 55502                       1
# 113638                      0
# 114708                      1
# 132815                      1
# 148092                      0
# ...                       ...
# 32167939                    1
# 32168520                    0
# 32169200                    1
# 32169731                    0
# 32171759                    0
#
# [10470 rows x 16 columns]

# %%
df_teacher_stats
# Out:
#         user_id  finished_session  response_rate  attendance_rate
# 0         55502              2689           1.00             1.00
# 1        113638              8410           1.00             1.00
# 2        114708                50           0.94             0.98
# 3        132815              2046           1.00             1.00
# 4        148092              4109           1.00             1.00
# ...         ...               ...            ...              ...
# 10465  32167939                 3           1.00             1.00
# 10466  32168520                 1           1.00             1.00
# 10467  32169200                 0           0.00             0.00
# 10468  32169731                 0           0.00             0.00
# 10469  32171759                 0           0.00             0.00
#
# [10470 rows x 4 columns]

# %%
df_teacher_stats.set_index('user_id', inplace=True)
df_teacher_stats
# Out:
#           finished_session  response_rate  attendance_rate
# user_id
# 55502                 2689           1.00             1.00
# 113638                8410           1.00             1.00
# 114708                  50           0.94             0.98
# 132815                2046           1.00             1.00
# 148092                4109           1.00             1.00
# ...                    ...            ...              ...
# 32167939                 3           1.00             1.00
# 32168520                 1           1.00             1.00
# 32169200                 0           0.00             0.00
# 32169731                 0           0.00             0.00
# 32171759                 0           0.00             0.00
#
# [10470 rows x 3 columns]

# %%
df_pro_course
# Out:
#            id  teacher_id language  \
# 0         375      436016  english
# 1         555      436016  chinese
# 2         946      502096  serbian
# 3        3190      436016  chinese
# 4        4042      463477  english
# ...       ...         ...      ...
# 39030  290784    31481128   french
# 39031  290785     8513543   french
# 39032  290788    29325526   korean
# 39033  290792     6417813  spanish
# 39034  290796    31472940   french
#
#                                                    title  session_price  \
# 0                                English courses新概念英语（1）           1400
# 1                                Young Learners' Chinese           1600
# 2      Serbian for all levels! 100% target language l...           2300
# 3                   One-on-One Customized Chinese lesson           1500
# 4                           One-on-One tutoring: English           3200
# ...                                                  ...            ...
# 39030     🗣️ Natural French Conversation: Speak easily !            700
# 39031                                      Leçon d'essai            800
# 39032                             For Long-term Students           1300
# 39033  DELE exam preparation / Preparación para el ex...           2700
# 39034                      French for Kids and Beginners           4000
#
#        student_count  session_count  has_package
# 0                 15            106            0
# 1                  5             37            1
# 2                 80           1113            1
# 3                 73           1391            1
# 4                 95           1504            1
# ...              ...            ...          ...
# 39030              0              0            1
# 39031              0              0            0
# 39032              0              0            1
# 39033              0              0            1
# 39034              0              0            1
#
# [39035 rows x 8 columns]

# %%
df_pro_course.set_index('id', inplace=True)
df_pro_course
# Out:
#         teacher_id language  \
# id
# 375         436016  english
# 555         436016  chinese
# 946         502096  serbian
# 3190        436016  chinese
# 4042        463477  english
# ...            ...      ...
# 290784    31481128   french
# 290785     8513543   french
# 290788    29325526   korean
# 290792     6417813  spanish
# 290796    31472940   french
#
#                                                     title  session_price  \
# id
# 375                               English courses新概念英语（1）           1400
# 555                               Young Learners' Chinese           1600
# 946     Serbian for all levels! 100% target language l...           2300
# 3190                 One-on-One Customized Chinese lesson           1500
# 4042                         One-on-One tutoring: English           3200
# ...                                                   ...            ...
# 290784     🗣️ Natural French Conversation: Speak easily !            700
# 290785                                      Leçon d'essai            800
# 290788                             For Long-term Students           1300
# 290792  DELE exam preparation / Preparación para el ex...           2700
# 290796                      French for Kids and Beginners           4000
#
#         student_count  session_count  has_package
# id
# 375                15            106            0
# 555                 5             37            1
# 946                80           1113            1
# 3190               73           1391            1
# 4042               95           1504            1
# ...               ...            ...          ...
# 290784              0              0            1
# 290785              0              0            0
# 290788              0              0            1
# 290792              0              0            1
# 290796              0              0            1
#
# [39035 rows x 7 columns]

# %%
df_price_list
# Out:
#         package_price  session_price  course_id  package_length  \
# 0                1100           1100        375               1
# 1               10000           1000        555              10
# 2               20900           2300        946              10
# 3               12000           1300       3190              10
# 4               10000           1000       3190              10
# ...               ...            ...        ...             ...
# 215822          10200           1100     287665              10
# 215823          15000           1100     287665              15
# 215824          20000           1100     287665              20
# 215825          59999           7498      87801              10
# 215826          84999           7498      87801              15
#
#         session_length  course_price_id
# 0                    3              336
# 1                    2              494
# 2                    4              823
# 3                    3             3075
# 4                    2             3076
# ...                ...              ...
# 215822               3          1084998
# 215823               3          1084999
# 215824               3          1085000
# 215825               4          1085029
# 215826               4          1085030
#
# [215827 rows x 6 columns]

# %%
df_price_list.set_index('course_price_id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df_price_list.set_index('course_price_id', inplace=True)
#       2 df_price_list
#
# File c:\Users\pecke\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6977, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6973                     if not found:
#    6974                         missing.append(col)
#    6975
#    6976         if missing:
# -> 6977             raise KeyError(f"None of {missing} are in the columns")
#    6978
#    6979         if inplace:
#    6980             frame = self
#
# KeyError: "None of ['course_price_id'] are in the columns"

# %%
df_price_list
# Out:
#                  package_price  session_price  course_id  package_length  \
# course_price_id
# 336                       1100           1100        375               1
# 494                      10000           1000        555              10
# 823                      20900           2300        946              10
# 3075                     12000           1300       3190              10
# 3076                     10000           1000       3190              10
# ...                        ...            ...        ...             ...
# 1084998                  10200           1100     287665              10
# 1084999                  15000           1100     287665              15
# 1085000                  20000           1100     287665              20
# 1085029                  59999           7498      87801              10
# 1085030                  84999           7498      87801              15
#
#                  session_length
# course_price_id
# 336                           3
# 494                           2
# 823                           4
# 3075                          3
# 3076                          2
# ...                         ...
# 1084998                       3
# 1084999                       3
# 1085000                       3
# 1085029                       4
# 1085030                       4
#
# [215827 rows x 5 columns]

# %%
df_also_speaks_reference
# Out:
#                      0
# 0              spanish
# 1               arabic
# 2     arabic(maghrebi)
# 3    filipino(tagalog)
# 4             japanese
# ..                 ...
# 205           friulian
# 206      luxembourgish
# 207           malagasy
# 208        greenlandic
# 209            frisian
#
# [210 rows x 1 columns]

# %%
df_also_speaks_reference = df_also_speaks_reference.reset_index()
df_also_speaks_reference = df_also_speaks_reference.rename(columns={0:'language'})

# %%
df_also_speaks_reference.set_index('index', inplace=True)
df_also_speaks_reference
# Out:
#                 language
# index
# 0                spanish
# 1                 arabic
# 2       arabic(maghrebi)
# 3      filipino(tagalog)
# 4               japanese
# ...                  ...
# 205             friulian
# 206        luxembourgish
# 207             malagasy
# 208          greenlandic
# 209              frisian
#
# [210 rows x 1 columns]

# %%
df_also_speaks.set_index('user_id', inplace=True)
df_also_speaks
# Out:
#           language
# user_id
# 5467830          0
# 5467830          1
# 5467830          2
# 11401921         3
# 11401921         4
# ...            ...
# 23372570         4
# 23372570         0
# 8296973        180
# 8296973         12
# 8296973         11
#
# [29185 rows x 1 columns]

# %%
database_schema = {
    'user_course_info_table': df_user_course_info,
    'teacher_stats_table': df_teacher_stats,
    'pro_course_table': df_pro_course,
    'price_list_table': df_price_list,
    'other_languages_table': df_also_speaks,
    'other_languages_ref_table': df_also_speaks_reference
}

# %%
conn = sqlite3.connect('italki_analytics.db')

for table_name, dataframe in database_schema.items():
    
    # Check if the index has an explicit name assigned
    if dataframe.index.name is not None:
        pk_label = dataframe.index.name
    else:
        pk_label = 'id' 
    
    # Write cleanly to SQLite
    dataframe.to_sql(
        name=table_name, 
        con=conn, 
        if_exists='replace', 
        index=True, 
        index_label=pk_label
    )
    print(f"Successfully loaded '{table_name}' using primary key: {pk_label}")

# Always close the connection for DB Browser access
conn.close()
# Out:
# Successfully loaded 'user_course_info_table' using primary key: user_id
# Successfully loaded 'teacher_stats_table' using primary key: user_id
# Successfully loaded 'pro_course_table' using primary key: id
# Successfully loaded 'price_list_table' using primary key: course_price_id
# Successfully loaded 'other_languages_table' using primary key: user_id
# Successfully loaded 'other_languages_ref_table' using primary key: index
