# %%
import pandas as pd
import json
from datetime import datetime
from zoneinfo import ZoneInfo

# %% [markdown]
# Check duplicates for User and Course Info

# %%
with open('../data_extraction/user_course_info.json', 'r') as file:
    user_course_info_check = json.load(file)

df_user_course_info_check = pd.DataFrame(user_course_info_check)

# %%
df_user_course_info_check
# Out:
#         user_id              nickname  is_tutor  is_pro origin_country_id  \
# 0       5467830   ⭐Learn with Kim/Kin         1       0                CN
# 1      11401921          Teacher Emee         1       0                PH
# 2       9627036        Shyam Syangtan         1       0                IN
# 3       5787377        Kimi(y)a 👩🏻🎓❤️         1       0                IR
# 4       9934037             Anne Rola         1       0                PH
# ...         ...                   ...       ...     ...               ...
# 11164   8392625           Yunhee Jung         1       0                US
# 11165   9170372              Hera 최해라         1       1                KR
# 11166  23372570    MyKoreanTeacherDan         0       1                NZ
# 11167   8296973  Leeji 리지(Ji Eun Lee)         0       1                KR
# 11168  21737274                 Julia         1       0                KR
#
#       living_country_id origin_city_id  origin_city_name living_city_id  \
# ...

# %%
list(df_user_course_info_check.columns)
# Out:
# ['user_id',
#  'nickname',
#  'is_tutor',
#  'is_pro',
#  'origin_country_id',
#  'living_country_id',
#  'origin_city_id',
#  'origin_city_name',
#  'living_city_id',
#  'living_city_name',
#  'timezone',
#  'trial_length',
#  'has_trial',
#  'trial_price',
#  'min_price',
#  'trial_session_count',
#  'has_beginner_course']

# %%
columns_user = ['user_id',
 'nickname',
 'is_tutor',
 'is_pro',
 'origin_country_id',
 'living_country_id',
 'origin_city_id',
 'origin_city_name',
 'living_city_id',
 'living_city_name',
 'timezone']

# %% [markdown]
# Check if there are users that appear more than twice

# %%
df_user_dup = df_user_course_info_check[df_user_course_info_check[['user_id', 'nickname']].duplicated(keep=False)]

# %%
df_unique = df_user_dup.groupby(['user_id', 'nickname']).count()
# df_unique = df_unique.reset_index(names='user_id')

# %%
df_unique
# Out:
#                               is_tutor  is_pro  origin_country_id  \
# user_id  nickname
# 495195   Maria Exam Work etc         2       2                  2
# 707465   Andrea                      2       2                  2
# 719539   Teddy                       2       2                  2
# 745006   Rose                        2       2                  2
# 755999   Tati                        2       2                  2
# ...                                ...     ...                ...
# 30946403 Edoardo                     2       2                  2
# 31046452 Kohl Sandra                 2       2                  2
# 31264233 Valentin Bétourné           2       2                  2
# 31265601 Niko                        2       2                  2
# 31822868 Nikki Gevana                2       2                  2
#
#                               living_country_id  origin_city_id  \
# user_id  nickname
# 495195   Maria Exam Work etc                  2               2
# ...

# %% [markdown]
# Users that have multiple entries of the same user_id and same nickname are removed.\
# The latest one is kept because it means that they have updated some of their personal information

# %%
df_user_course_sorted = df_user_course_info_check.sort_values('user_id')
df_no_dup_id_nickname = df_user_course_sorted.drop_duplicates(subset=['user_id', 'nickname'], keep='last')
df_no_dup_id_nickname
# Out:
#         user_id           nickname  is_tutor  is_pro origin_country_id  \
# 5833      55502         Micky Mick         1       0                CN
# 5929     113638                Xin         1       1                CN
# 5642     114708  Amy (Féng lǎoshī）         0       1                CN
# 10791    132815           Julie 줄리         1       0                KR
# 7858     148092         Jhon Jairo         0       1                CO
# ...         ...                ...       ...     ...               ...
# 4655   32167939            Andrele         1       0                CA
# 220    32168520         Daphne👩🏫🌸💗         1       0                PH
# 4152   32169200  Davide Castellani         1       0                IT
# 4150   32169731      FelixRansford         1       0                GB
# 4439   32171759      Roselene Noel         1       0                HT
#
#       living_country_id origin_city_id origin_city_name living_city_id  \
# ...

# %%
# diff = df_unique.compare(df_unique_all)

# %%
user_course_info_cleaned = df_no_dup_id_nickname.to_dict(orient='records')

# %%
user_course_info_cleaned
# Out:
# [{'user_id': 55502,
#   'nickname': 'Micky Mick',
#   'is_tutor': 1,
#   'is_pro': 0,
#   'origin_country_id': 'CN',
#   'living_country_id': 'CN',
#   'origin_city_id': 'CN00226',
#   'origin_city_name': 'Fushun',
#   'living_city_id': 'CN00006',
#   'living_city_name': 'Beijing',
#   'timezone': 'Asia/Shanghai',
#   'trial_length': 2,
#   'has_trial': 0,
#   'trial_price': 1000,
#   'min_price': 2000,
#   'trial_session_count': 97,
#   'has_beginner_course': 1},
#  {'user_id': 113638,
#   'nickname': 'Xin',
#   'is_tutor': 1,
#   'is_pro': 1,
#   'origin_country_id': 'CN',
#   'living_country_id': 'CA',
#   'origin_city_id': '',
#   'origin_city_name': '',
#   'living_city_id': 'CA00006',
#   'living_city_name': 'Montreal',
#   'timezone': 'America/Toronto',
#   'trial_length': 2,
#   'has_trial': 0,
#   'trial_price': 999,
#   'min_price': 2500,
#   'trial_session_count': 227,
#   'has_beginner_course': 0},
#  {'user_id': 114708,
#   'nickname': 'Amy (Féng lǎoshī）',
# ...

# %% [markdown]
# Check if 'has_trial' column in the users and trial table indicates 0 but trial count is more than 1.\
# From the code block below, all users have the column 'has_trial' as 0.\
# This means that if the trial price is greater than 0 or the trial session count is greater than 0, it does not matter what the 'has_trial' indicates\
# Hence the has_trial column should not be used.

# %%
df_no_dup_id_nickname[df_no_dup_id_nickname['has_trial'] == 0].count()
# Out:
# user_id                10470
# nickname               10470
# is_tutor               10470
# is_pro                 10470
# origin_country_id      10470
# living_country_id      10470
# origin_city_id         10470
# origin_city_name       10470
# living_city_id         10470
# living_city_name       10470
# timezone               10470
# trial_length           10470
# has_trial              10470
# trial_price            10470
# min_price              10470
# trial_session_count    10470
# has_beginner_course    10470
# dtype: int64

# %%
with open('./user_course_info_cleaned.json', 'w') as file:
        json.dump(user_course_info_cleaned, file, indent=4)

# %%
df_no_dup_id_nickname[df_no_dup_id_nickname['user_id'] == 1689306]
# Out:
#       user_id           nickname  is_tutor  is_pro origin_country_id  \
# 5228  1689306  Cristina Domènech         0       1                ES
#
#      living_country_id origin_city_id origin_city_name living_city_id  \
# 5228                NL        ES00006        Barcelona        NL00111
#
#      living_city_name          timezone  trial_length  has_trial  trial_price  \
# 5228           Leiden  Europe/Amsterdam             2          0         4600
#
#       min_price  trial_session_count  has_beginner_course
# 5228       7400                 1116                    1

# %% [markdown]
# Check duplicates in teacher_stats

# %%
with open('../data_extraction/teacher_stats.json', 'r') as file:
    teacher_stats_check = json.load(file)

df_teacher_statscheck = pd.DataFrame(teacher_stats_check)

# %%
df_teacher_statscheck
# Out:
#         user_id  finished_session  response_rate  attendance_rate
# 0       5467830              4220           1.00             1.00
# 1      11401921              7443           1.00             1.00
# 2       9627036              6346           1.00             1.00
# 3       5787377              5007           1.00             1.00
# 4       9934037              2664           1.00             0.99
# ...         ...               ...            ...              ...
# 11032   8712350              1143           1.00             1.00
# 11033   8392625               364           0.98             0.99
# 11034   9170372              5033           1.00             1.00
# 11035  23372570                12           1.00             1.00
# 11036   8296973              1287           1.00             1.00
#
# [11037 rows x 4 columns]

# %%
df_teacher_stats_dup = df_teacher_statscheck[df_teacher_statscheck[['user_id']].duplicated(keep=False)]

# %%
df_teacher_stats_dup
# Out:
#         user_id  finished_session  response_rate  attendance_rate
# 0       5467830              4220           1.00             1.00
# 5       7023372              4547           1.00             1.00
# 76     28084220               269           1.00             1.00
# 93     10599672              1068           1.00             1.00
# 98      7603855               404           0.99             0.98
# ...         ...               ...            ...              ...
# 10945   3524894              7374           1.00             1.00
# 10951  11663378              1443           1.00             1.00
# 10952   5728578              4621           1.00             1.00
# 10956    815733              3168           0.99             1.00
# 10964  23907480              1021           1.00             1.00
#
# [1122 rows x 4 columns]

# %%
df_teacher_stats_count = df_teacher_stats_dup.groupby('user_id').count()
df_teacher_stats_count
# Out:
#           finished_session  response_rate  attendance_rate
# user_id
# 222305                   3              3                3
# 495195                   2              2                2
# 502096                   2              2                2
# 706352                   2              2                2
# 707465                   2              2                2
# ...                    ...            ...              ...
# 30739843                 2              2                2
# 30934061                 2              2                2
# 31068665                 2              2                2
# 31265601                 2              2                2
# 31823132                 2              2                2
#
# [555 rows x 3 columns]

# %%
df_teacher_stats_count[df_teacher_stats_count['finished_session'] >= 4].count()
# Out:
# finished_session    0
# response_rate       0
# attendance_rate     0
# dtype: int64

# %%
df_teacher_stats_sorted = df_teacher_statscheck.sort_values('user_id')
df_teacher_stats_no_dup = df_teacher_stats_sorted.drop_duplicates(subset=['user_id'], keep='last')
df_teacher_stats_no_dup
# Out:
#         user_id  finished_session  response_rate  attendance_rate
# 5838      55502              2689           1.00             1.00
# 5933     113638              8410           1.00             1.00
# 5648     114708                50           0.94             0.98
# 10675    132815              2046           1.00             1.00
# 7838     148092              4109           1.00             1.00
# ...         ...               ...            ...              ...
# 4659   32167939                 3           1.00             1.00
# 220    32168520                 1           1.00             1.00
# 4152   32169200                 0           0.00             0.00
# 4150   32169731                 0           0.00             0.00
# 4439   32171759                 0           0.00             0.00
#
# [10470 rows x 4 columns]

# %%
df_teacher_statscheck
df_teacher_statscheck[df_teacher_statscheck['user_id'] == 1689306]
# Out:
#       user_id  finished_session  response_rate  attendance_rate
# 4077  1689306             15479            1.0              1.0
# 5247  1689306             15488            1.0              1.0

# %%
df_teacher_stats_no_dup[df_teacher_stats_no_dup['user_id'] == 1689306]
# Out:
#       user_id  finished_session  response_rate  attendance_rate
# 5247  1689306             15488            1.0              1.0

# %%
teacher_stats_cleaned = df_teacher_stats_no_dup.to_dict(orient='records')

# %%
teacher_stats_cleaned
# Out:
# [{'user_id': 55502,
#   'finished_session': 2689,
#   'response_rate': 1.0,
#   'attendance_rate': 1.0},
#  {'user_id': 113638,
#   'finished_session': 8410,
#   'response_rate': 1.0,
#   'attendance_rate': 1.0},
#  {'user_id': 114708,
#   'finished_session': 50,
#   'response_rate': 0.94,
#   'attendance_rate': 0.98},
#  {'user_id': 132815,
#   'finished_session': 2046,
#   'response_rate': 1.0,
#   'attendance_rate': 1.0},
#  {'user_id': 148092,
#   'finished_session': 4109,
#   'response_rate': 1.0,
#   'attendance_rate': 1.0},
#  {'user_id': 222305,
#   'finished_session': 14061,
#   'response_rate': 1.0,
#   'attendance_rate': 1.0},
#  {'user_id': 249152,
#   'finished_session': 1249,
#   'response_rate': 0.97,
#   'attendance_rate': 0.99},
#  {'user_id': 259649,
#   'finished_session': 8798,
#   'response_rate': 1.0,
#   'attendance_rate': 0.99},
#  {'user_id': 291538,
#   'finished_session': 2503,
#   'response_rate': 0.98,
#   'attendance_rate': 0.98},
#  {'user_id': 316582,
# ...

# %%
with open('./teacher_stats_cleaned.json', 'w') as file:
        json.dump(teacher_stats_cleaned, file, indent=4)

# %% [markdown]
# Check if tutors have no pro course

# %%
with open('../data_extraction/pro_course.json', 'r') as file:
    pro_course_check = json.load(file)

df_pro_course_check = pd.DataFrame(pro_course_check)

# %%
df_pro_course_count = df_pro_course_check.groupby('teacher_id').count()
df_pro_course_count
# Out:
#             id  language  title  session_price  student_count  session_count  \
# teacher_id
# 55502        3         3      3              3              3              3
# 113638       4         4      4              4              4              4
# 114708       4         4      4              4              4              4
# 132815       5         5      5              5              5              5
# 148092       4         4      4              4              4              4
# ...         ..       ...    ...            ...            ...            ...
# 32167939     2         2      2              2              2              2
# 32168520     3         3      3              3              3              3
# 32169200     1         1      1              1              1              1
# 32169731     1         1      1              1              1              1
# 32171759     1         1      1              1              1              1
#
#             has_package
# ...

# %%
df_pro_course_count[df_pro_course_count['id'] > 0]
# Out:
#             id  language  title  session_price  student_count  session_count  \
# teacher_id
# 55502        3         3      3              3              3              3
# 113638       4         4      4              4              4              4
# 114708       4         4      4              4              4              4
# 132815       5         5      5              5              5              5
# 148092       4         4      4              4              4              4
# ...         ..       ...    ...            ...            ...            ...
# 32167939     2         2      2              2              2              2
# 32168520     3         3      3              3              3              3
# 32169200     1         1      1              1              1              1
# 32169731     1         1      1              1              1              1
# 32171759     1         1      1              1              1              1
#
#             has_package
# ...

# %% [markdown]
# Pro Course Cleaned JSON generated below when checking if there are duplicated pro courses

# %% [markdown]
# Check for any duplicates in the also speaks file\
# Check if there are teachers in the 'also_speaks' file but missing in the 'user_course_info' file.

# %%
with open('../data_extraction/also_speaks.json', 'r') as file:
    also_speaks_check = json.load(file)

df_also_speaks = pd.DataFrame(also_speaks_check)

# %% [markdown]
# No exact duplicates found in the also speaks dataframe.\
# Exact duplicates need to be checked because with the user_course_info table, there is a one to many relationship.\
# There are teachers who speak multiple other languages so they will have multiple entries in the 'also speaks' table

# %%
all_duplicates = df_also_speaks[df_also_speaks.duplicated(keep=False)]
all_duplicates
# Out:
# Empty DataFrame
# Columns: [user_id, language]
# Index: []

# %%
with open('./user_course_info_cleaned.json', 'r') as file:
    user_course_info = json.load(file)

df_user_course_info = pd.DataFrame(user_course_info)

# %%
df_num_of_languages = df_also_speaks.groupby('user_id').count().reset_index()

# %%
df_num_of_languages[df_num_of_languages['language'] > 0]
# Out:
#         user_id  language
# 0         55502         3
# 1        113638         2
# 2        114708         4
# 3        132815         2
# 4        148092         3
# ...         ...       ...
# 10289  32167939         3
# 10290  32168520         1
# 10291  32169200         1
# 10292  32169731         1
# 10293  32171759         4
#
# [10294 rows x 2 columns]

# %%
df_merged = pd.merge(df_user_course_info, df_num_of_languages, on='user_id', how='left_anti')

# %% [markdown]
# Doing a sample check on these teachers that are in the user_info_cleaned file but not in the also_speaks file, these 176 teachers do in fact only speak one language. Hence they do not appear in the also_speaks file.\
# Using the 'right-anti' there are no teachers who appear in the also speaks file but not in the users file.

# %%
df_merged
# Out:
#         user_id           nickname  is_tutor  is_pro origin_country_id  \
# 36       595157           Consuelo         1       1                ES
# 44       652005  Scarlet  Lorraine         1       1                ZZ
# 58       754979      Daniel Colman         0       1                GB
# 63       795706            Natalia         1       1                RU
# 89       896917     Faith Valencia         1       0                PH
# ...         ...                ...       ...     ...               ...
# 9400   27642857       SAMANTHA KVD         1       0                KE
# 9986   30333130             Marcus         0       1                US
# 9994   30344307  Professeure Gilee         1       0                CA
# 10284  31409112          Mojomarty         1       0                US
# 10393  31823132        Nova L-Zine         1       0                DZ
#
#       living_country_id origin_city_id origin_city_name living_city_id  \
# ...

# %%
df_merged = pd.merge(df_user_course_info, df_num_of_languages, on='user_id', how='right_anti')

# %%
df_merged
# Out:
# Empty DataFrame
# Columns: [user_id, nickname, is_tutor, is_pro, origin_country_id, living_country_id, origin_city_id, origin_city_name, living_city_id, living_city_name, timezone, trial_length, has_trial, trial_price, min_price, trial_session_count, has_beginner_course, language]
# Index: []

# %%
also_speaks_cleaned = df_also_speaks.to_dict(orient='records')

# %%
also_speaks_cleaned
# Out:
# [{'user_id': 5467830, 'language': 0},
#  {'user_id': 5467830, 'language': 1},
#  {'user_id': 5467830, 'language': 2},
#  {'user_id': 11401921, 'language': 3},
#  {'user_id': 11401921, 'language': 4},
#  {'user_id': 11401921, 'language': 5},
#  {'user_id': 9627036, 'language': 6},
#  {'user_id': 9627036, 'language': 7},
#  {'user_id': 5787377, 'language': 8},
#  {'user_id': 5787377, 'language': 9},
#  {'user_id': 5787377, 'language': 10},
#  {'user_id': 5787377, 'language': 1},
#  {'user_id': 5787377, 'language': 11},
#  {'user_id': 5787377, 'language': 12},
#  {'user_id': 5787377, 'language': 0},
#  {'user_id': 9934037, 'language': 3},
#  {'user_id': 9934037, 'language': 5},
#  {'user_id': 7023372, 'language': 0},
#  {'user_id': 7023372, 'language': 13},
#  {'user_id': 7023372, 'language': 12},
#  {'user_id': 7023372, 'language': 14},
#  {'user_id': 7023372, 'language': 1},
#  {'user_id': 7023372, 'language': 7},
#  {'user_id': 7023372, 'language': 5},
# ...

# %%
with open('./also_speaks_cleaned.json', 'w') as file:
        json.dump(also_speaks_cleaned, file, indent=4)

# %% [markdown]
# Check that Every Pro Course is tagged to a teacher.\
# There are teachers with multiple pro courses.

# %%
with open('./user_course_info_cleaned.json', 'r') as file:
    user_course_info = json.load(file)

df_user_course_info = pd.DataFrame(user_course_info)

# %%
with open('../data_extraction/pro_course.json', 'r') as file:
    pro_course_check = json.load(file)

df_pro_course_check = pd.DataFrame(pro_course_check)

# %%
df_pro_course_check
# Out:
#            id  teacher_id language  \
# 0      146280     5467830  chinese
# 1      146282     5467830  chinese
# 2      148875     5467830  chinese
# 3      186046     5467830  english
# 4      186049     5467830  english
# ...       ...         ...      ...
# 40066  249718    23372570   korean
# 40067  249721    23372570   korean
# 40068  139499     8296973   korean
# 40069  139502     8296973   korean
# 40070  139510     8296973   korean
#
#                                                    title  session_price  \
# 0      【For new student】 Customized Lesson (A1~C2）  /...           6000
# 1      【Special discount for long-term students who h...           5800
# 2      (No Video & No Audio Call) Essay Correction wi...            500
# 3             【For new student 新生课】 个人定制课程  / カスタマイズレッスン           6000
# 4      【无需见面的作文修改】 (No Video  & No Audio Call)  / Ess...            500
# ...                                                  ...            ...
# ...

# %% [markdown]
# The following code block shows that every course has a teacher mapped to it.

# %%
df_merged = pd.merge(df_user_course_info, df_pro_course_check, left_on='user_id', right_on='teacher_id', how='right_anti')
df_merged
# Out:
# Empty DataFrame
# Columns: [user_id, nickname, is_tutor, is_pro, origin_country_id, living_country_id, origin_city_id, origin_city_name, living_city_id, living_city_name, timezone, trial_length, has_trial, trial_price, min_price, trial_session_count, has_beginner_course, id, teacher_id, language, title, session_price, student_count, session_count, has_package]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# The following code block shows that the number of teachers in the pro course table matches the user_course_info table as there are 10470 unique teachers

# %%
df_pro_course_check.groupby('teacher_id').count()
# Out:
#             id  language  title  session_price  student_count  session_count  \
# teacher_id
# 55502        3         3      3              3              3              3
# 113638       4         4      4              4              4              4
# 114708       4         4      4              4              4              4
# 132815       5         5      5              5              5              5
# 148092       4         4      4              4              4              4
# ...         ..       ...    ...            ...            ...            ...
# 32167939     2         2      2              2              2              2
# 32168520     3         3      3              3              3              3
# 32169200     1         1      1              1              1              1
# 32169731     1         1      1              1              1              1
# 32171759     1         1      1              1              1              1
#
#             has_package
# ...

# %%
df_pro_course_check['teacher_id'].nunique()
# Out:
# 10470

# %% [markdown]
# There are duplicate pro course id which should not be the case.\
# If there id, teacher_id and the language are the same, the later one should be taken meaning sort by id and session count.\
# The higher session count will be taken

# %%
df_pro_course_check['id'].nunique()
# Out:
# 39035

# %%
df_pro_course_check_id = df_pro_course_check.groupby('id').count().reset_index()

# %%
df_pro_course_check_id
# Out:
#            id  teacher_id  language  title  session_price  student_count  \
# 0         375           1         1      1              1              1
# 1         555           1         1      1              1              1
# 2         946           2         2      2              2              2
# 3        3190           1         1      1              1              1
# 4        4042           1         1      1              1              1
# ...       ...         ...       ...    ...            ...            ...
# 39030  290784           1         1      1              1              1
# 39031  290785           1         1      1              1              1
# 39032  290788           1         1      1              1              1
# 39033  290792           1         1      1              1              1
# 39034  290796           1         1      1              1              1
#
#        session_count  has_package
# 0                  1            1
# ...

# %%
df_pro_course_check[df_pro_course_check['id'] == 946]
# Out:
#         id  teacher_id language  \
# 11617  946      502096  serbian
# 35999  946      502096  serbian
#
#                                                    title  session_price  \
# 11617  Serbian for all levels! 100% target language l...           2300
# 35999  Serbian for all levels! 100% target language l...           2300
#
#        student_count  session_count  has_package
# 11617             80           1112            1
# 35999             80           1113            1

# %% [markdown]
# There are 40071 rows in the pro course table but only 39035 unique ids.

# %%
all_duplicates = df_pro_course_check[df_pro_course_check.duplicated(subset=['id', 'teacher_id', 'language'], keep=False)]
all_duplicates
# Out:
#            id  teacher_id language  \
# 0      146280     5467830  chinese
# 41     101184     7023372  russian
# 43     101662     7023372  english
# 47     258619     7023372  russian
# 384    269540    28084220  english
# ...       ...         ...      ...
# 39814  221255     5728578   korean
# 39815  247686     5728578   korean
# 39847  251333    23907480   korean
# 39858  253792    24885652   korean
# 39867  166826     9484347  english
#
#                                                    title  session_price  \
# 0      【For new student】 Customized Lesson (A1~C2）  /...           6000
# 41     🇷🇺 General Course - Russian for Beginners (A0-A2)           2500
# 43     🇺🇲🇨🇦🇬🇧 General English Course (Including Engli...           3000
# 47     🇷🇺 NEW! Russian for Kids and Teenagers - Русск...           2500
# 384       Free-Form Conversation in English (For adults)            690
# ...                                                  ...            ...
# ...

# %%
pro_count_dup_count = all_duplicates.groupby('id').count().reset_index()
pro_count_dup_count
# Out:
#           id  teacher_id  language  title  session_price  student_count  \
# 0        946           2         2      2              2              2
# 1      11943           2         2      2              2              2
# 2      13127           2         2      2              2              2
# 3      13362           2         2      2              2              2
# 4      14210           2         2      2              2              2
# ...      ...         ...       ...    ...            ...            ...
# 1022  289067           2         2      2              2              2
# 1023  289068           2         2      2              2              2
# 1024  289069           2         2      2              2              2
# 1025  289287           2         2      2              2              2
# 1026  290415           2         2      2              2              2
#
#       session_count  has_package
# 0                 2            2
# 1                 2            2
# ...

# %%
pro_count_dup_count[pro_count_dup_count['teacher_id'] == 2]
# Out:
#           id  teacher_id  language  title  session_price  student_count  \
# 0        946           2         2      2              2              2
# 1      11943           2         2      2              2              2
# 2      13127           2         2      2              2              2
# 3      13362           2         2      2              2              2
# 4      14210           2         2      2              2              2
# ...      ...         ...       ...    ...            ...            ...
# 1022  289067           2         2      2              2              2
# 1023  289068           2         2      2              2              2
# 1024  289069           2         2      2              2              2
# 1025  289287           2         2      2              2              2
# 1026  290415           2         2      2              2              2
#
#       session_count  has_package
# 0                 2            2
# 1                 2            2
# ...

# %%
df_sorted = all_duplicates.sort_values(by=['teacher_id', 'id', 'session_count'], ascending=[True, True, True])
df_sorted
# Out:
#            id  teacher_id    language  \
# 4869    11943      222305  portuguese
# 19299   11943      222305  portuguese
# 4871    21847      222305      german
# 19300   21847      222305      german
# 4875    40640      222305      german
# ...       ...         ...         ...
# 20448  286810    31265601     italian
# 918    288579    31823132     english
# 18422  288579    31823132     english
# 919    288693    31823132      french
# 18423  288693    31823132      french
#
#                                                    title  session_price  \
# 4869                                           Português           1499
# 19299                                          Português           1499
# 4871                                              German           1499
# 19300                                             German           1499
# 4875                                             Deutsch           1499
# ...

# %%
df_pro_course_sorted = df_pro_course_check.sort_values(by=['id', 'teacher_id', 'session_count'], ascending=[True, True, True])
df_pro_course_no_dup = df_pro_course_sorted.drop_duplicates(subset=['id', 'teacher_id', 'language'], keep='last')
df_pro_course_no_dup
# Out:
#            id  teacher_id language  \
# 22570     375      436016  english
# 22571     555      436016  chinese
# 35999     946      502096  serbian
# 22572    3190      436016  chinese
# 14692    4042      463477  english
# ...       ...         ...      ...
# 18747  290784    31481128   french
# 18455  290785     8513543   french
# 38856  290788    29325526   korean
# 29884  290792     6417813  spanish
# 21580  290796    31472940   french
#
#                                                    title  session_price  \
# 22570                            English courses新概念英语（1）           1400
# 22571                            Young Learners' Chinese           1600
# 35999  Serbian for all levels! 100% target language l...           2300
# 22572               One-on-One Customized Chinese lesson           1500
# 14692                       One-on-One tutoring: English           3200
# ...                                                  ...            ...
# ...

# %%
df_pro_course_no_dup[df_pro_course_no_dup['id'] == 946]
# Out:
#         id  teacher_id language  \
# 35999  946      502096  serbian
#
#                                                    title  session_price  \
# 35999  Serbian for all levels! 100% target language l...           2300
#
#        student_count  session_count  has_package
# 35999             80           1113            1

# %%
pro_course_cleaned = df_pro_course_no_dup.to_dict(orient='records')

# %%
pro_course_cleaned
# Out:
# [{'id': 375,
#   'teacher_id': 436016,
#   'language': 'english',
#   'title': 'English courses新概念英语（1）',
#   'session_price': 1400,
#   'student_count': 15,
#   'session_count': 106,
#   'has_package': 0},
#  {'id': 555,
#   'teacher_id': 436016,
#   'language': 'chinese',
#   'title': "Young Learners' Chinese",
#   'session_price': 1600,
#   'student_count': 5,
#   'session_count': 37,
#   'has_package': 1},
#  {'id': 946,
#   'teacher_id': 502096,
#   'language': 'serbian',
#   'title': 'Serbian for all levels! 100% target language lessons!',
#   'session_price': 2300,
#   'student_count': 80,
#   'session_count': 1113,
#   'has_package': 1},
#  {'id': 3190,
#   'teacher_id': 436016,
#   'language': 'chinese',
#   'title': 'One-on-One Customized Chinese lesson',
#   'session_price': 1500,
#   'student_count': 73,
#   'session_count': 1391,
#   'has_package': 1},
#  {'id': 4042,
#   'teacher_id': 463477,
#   'language': 'english',
#   'title': 'One-on-One tutoring: English',
# ...

# %%
with open('./pro_course_cleaned.json', 'w') as file:
        json.dump(pro_course_cleaned, file, indent=4)

# %% [markdown]
# Check if there are duplicated price list items\
# Check if every price list item is linked to a course

# %%
with open('../data_extraction/price_list.json', 'r') as file:
    price_list = json.load(file)

df_price_list = pd.DataFrame(price_list)

# %%
with open('./pro_course_cleaned.json', 'r') as file:
    pro_course_cleaned = json.load(file)

df_pro_course_cleaned = pd.DataFrame(pro_course_cleaned)

# %%
df_price_list
# Out:
#         package_price  session_price  course_id  package_length  \
# 0               15200           3200     146280               5
# 1               22000           4600     146280               5
# 2               30000           6000     146280               5
# 3               59000           6000     146280              10
# 4               14300           3000     146282               5
# ...               ...            ...        ...             ...
# 216257          25000           5000     139499               5
# 216258          67500           5000     139499              15
# 216259           7000           7000     139502               1
# 216260          25000           5000     139510               5
# 216261          67500           5000     139510              15
#
#         session_length  course_price_id
# 0                    2           353199
# 1                    3           353200
# 2                    4           353198
# ...

# %% [markdown]
# There are duplicated price list items

# %%
df_price_list['course_price_id'].nunique()
# Out:
# 215827

# %% [markdown]
# There are 435 duplicated course_price_ids and there are no course_price_ids that occur 3 times or more.\
# From the sample check, the duplicates arise because of the teacher updating the prices or package/session length

# %%
df_price_list_dup = df_price_list.groupby('course_price_id').count()
df_price_list_dup.reset_index()
df_price_list_dup[df_price_list_dup['package_price'] > 1]
# Out:
#                  package_price  session_price  course_id  package_length  \
# course_price_id
# 137868                       2              2          2               2
# 137869                       2              2          2               2
# 145354                       2              2          2               2
# 151723                       2              2          2               2
# 151727                       2              2          2               2
# ...                        ...            ...        ...             ...
# 1082724                      2              2          2               2
# 1082725                      2              2          2               2
# 1082726                      2              2          2               2
# 1082907                      2              2          2               2
# 1083636                      2              2          2               2
#
#                  session_length
# course_price_id
# ...

# %%
all_duplicates = df_price_list[df_price_list.duplicated(subset=['course_price_id'], keep=False)]
all_duplicates
# Out:
#         package_price  session_price  course_id  package_length  \
# 5951             2600            600     288693               5
# 5952             5500            600     288693              10
# 5954             3000            700     288693               5
# 5956            10000            700     288693              15
# 5958             4000            900     290681               5
# ...               ...            ...        ...             ...
# 201593           7000           1400     274689               5
# 201594          14000           1400     274689              10
# 206621          23999           4999     107142               5
# 206622          47999           4999     107142              10
# 206623          69999           4999     107142              15
#
#         session_length  course_price_id
# 5951                 3          1065695
# 5952                 3          1072763
# 5954                 4          1065693
# ...

# %%
all_duplicates[all_duplicates['course_price_id'] == 1083636]
# Out:
#         package_price  session_price  course_id  package_length  \
# 5958             4000            900     290681               5
# 104896           4300            900     290681               5
#
#         session_length  course_price_id
# 5958                 4          1083636
# 104896               4          1083636

# %%
df_price_list_sorted = df_price_list.sort_values(by=['course_price_id', 'package_price', 'session_price'], ascending=[True, True, True])
df_price_list_no_dup = df_price_list_sorted.drop_duplicates(subset=['course_price_id', 'course_id'], keep='last')
df_price_list_no_dup
# Out:
#         package_price  session_price  course_id  package_length  \
# 127459           1100           1100        375               1
# 127461          10000           1000        555              10
# 67410           20900           2300        946              10
# 127467          12000           1300       3190              10
# 127465          10000           1000       3190              10
# ...               ...            ...        ...             ...
# 140883          10200           1100     287665              10
# 140884          15000           1100     287665              15
# 140885          20000           1100     287665              20
# 204373          59999           7498      87801              10
# 204374          84999           7498      87801              15
#
#         session_length  course_price_id
# 127459               3              336
# 127461               2              494
# 67410                4              823
# ...

# %%
df_pro_course_cleaned
# Out:
#            id  teacher_id language  \
# 0         375      436016  english
# 1         555      436016  chinese
# 2         946      502096  serbian
# 3        3190      436016  chinese
# 4        4042      463477  english
# ...       ...         ...      ...
# 39030  290784    31481128   french
# 39031  290785     8513543   french
# 39032  290788    29325526   korean
# 39033  290792     6417813  spanish
# 39034  290796    31472940   french
#
#                                                    title  session_price  \
# 0                                English courses新概念英语（1）           1400
# 1                                Young Learners' Chinese           1600
# 2      Serbian for all levels! 100% target language l...           2300
# 3                   One-on-One Customized Chinese lesson           1500
# 4                           One-on-One tutoring: English           3200
# ...                                                  ...            ...
# ...

# %% [markdown]
# When the pro course dataframe is joined with the cleaned price list data frame, both left-anti and right-anti join do not return any rows.\
# This means that there are no ids that are not mapped between the two tables.\
# All the prices are linked to a course.

# %%
df_merged = pd.merge(df_pro_course_cleaned, df_price_list_no_dup, left_on='id', right_on='course_id', how='right_anti')
# df_merged = pd.merge(df_pro_course_cleaned, df_price_list_no_dup, left_on='id', right_on='course_id', how='left_anti')
df_merged
# Out:
# Empty DataFrame
# Columns: [id, teacher_id, language, title, session_price_x, student_count, session_count, has_package, package_price, session_price_y, course_id, package_length, session_length, course_price_id]
# Index: []

# %%
price_list_cleaned = df_price_list_no_dup.to_dict(orient='records')

# %%
price_list_cleaned
# Out:
# [{'package_price': 1100,
#   'session_price': 1100,
#   'course_id': 375,
#   'package_length': 1,
#   'session_length': 3,
#   'course_price_id': 336},
#  {'package_price': 10000,
#   'session_price': 1000,
#   'course_id': 555,
#   'package_length': 10,
#   'session_length': 2,
#   'course_price_id': 494},
#  {'package_price': 20900,
#   'session_price': 2300,
#   'course_id': 946,
#   'package_length': 10,
#   'session_length': 4,
#   'course_price_id': 823},
#  {'package_price': 12000,
#   'session_price': 1300,
#   'course_id': 3190,
#   'package_length': 10,
#   'session_length': 3,
#   'course_price_id': 3075},
#  {'package_price': 10000,
#   'session_price': 1000,
#   'course_id': 3190,
#   'package_length': 10,
#   'session_length': 2,
#   'course_price_id': 3076},
#  {'package_price': 30500,
#   'session_price': 3200,
#   'course_id': 4042,
#   'package_length': 10,
#   'session_length': 4,
#   'course_price_id': 3934},
#  {'package_price': 24300,
# ...

# %%
with open('./price_list_cleaned.json', 'w') as file:
        json.dump(price_list_cleaned, file, indent=4)
