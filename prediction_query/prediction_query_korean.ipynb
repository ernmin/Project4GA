# %%
import pandas as pd
import json
import plotly.express as px
import numpy as np
import seaborn as sns
from tqdm import tqdm

from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn import tree

from openai import OpenAI
from config import pdf_key

# %% [markdown]
# The purpose of this notebook is to test the auto-categorization of each course using Open AI's API.\
# The initial hypothesis was that the type of course would impact the price of the course.\
# However, after a sample test using the Korean teachers, including the course category did not improve the RMSE nor R-Squared Value.

# %%
client = OpenAI(api_key=pdf_key)
tqdm.pandas()

# %%
with open('./user_course_info_cleaned.json', 'r') as file:
    user_course_info = json.load(file)

df_user_course_info = pd.DataFrame(user_course_info)

# %%
with open('./pro_course_cleaned.json', 'r') as file:
    pro_course = json.load(file)

df_pro_course = pd.DataFrame(pro_course)

# %% [markdown]
# Price Prediction Model Functions

# %%
def is_tutor(tutor):
    if tutor == True:
        df_tutors = df_user_course_info[(df_user_course_info['is_tutor'] == 1) & (df_user_course_info['is_pro']  == 0)]
        return df_tutors[['user_id', 'trial_session_count', 'trial_price']]
    else:
        df_pros_1 = df_user_course_info[(df_user_course_info['is_tutor'] == 1) & (df_user_course_info['is_pro']  == 1)]
        df_pros_2 = df_user_course_info[(df_user_course_info['is_tutor'] == 0) & (df_user_course_info['is_pro']  == 1)]
        df_pros_combined = pd.concat([df_pros_1, df_pros_2], ignore_index=True)
        df_pros_combined = df_pros_combined[['user_id', 'trial_session_count', 'trial_price']]
        return df_pros_combined
        
        
is_tutor(True)
# Out:
#         user_id  trial_session_count  trial_price
# 0         55502                   97         1000
# 3        132815                    0          750
# 6        249152                   70          800
# 11       355886                  142          500
# 12       368484                   91         1000
# ...         ...                  ...          ...
# 10465  32167939                    3         1000
# 10466  32168520                    0          500
# 10467  32169200                    0         1400
# 10468  32169731                    0          600
# 10469  32171759                    0          500
#
# [5639 rows x 3 columns]

# %%
def teacher_id_language(language):
    df_teachers_id = df_pro_course[df_pro_course['language'] == language].groupby(['teacher_id', 'language']).count()
    df_teachers_id = df_teachers_id.reset_index()
    df_teachers_id = df_teachers_id[['teacher_id']]
    return df_teachers_id

teacher_id_language('chinese')
# Out:
#      teacher_id
# 0         55502
# 1        113638
# 2        114708
# 3        259649
# 4        436016
# ..          ...
# 993    31845535
# 994    31847889
# 995    31913484
# 996    31915782
# 997    31915837
#
# [998 rows x 1 columns]

# %%
def pro_course_language(language):
    df_pro_course_target = df_pro_course[df_pro_course['language'] == language]
    return df_pro_course_target

pro_course_language('german')
# Out:
#            id  teacher_id language  \
# 11       9022      516278   german
# 12       9024      516278   german
# 20      10161      516278   german
# 87      20714      516278   german
# 103     21847      222305   german
# ...       ...         ...      ...
# 38971  290636    31827412   german
# 38980  290655    31079682   german
# 38981  290656    31079682   german
# 38994  290678    18952636   german
# 38998  290684     7330344   german
#
#                                                    title  session_price  \
# 11     ** GERMAN PROFICIENCY ★ 50 X 90 min ► All leve...           6090
# 12     ★ NEXT LEVEL GERMAN ★ 40 X 90 min ► All levels...           6090
# 20     ★ GERMAN IMMERSION ★ 30 X 90 min ► All levels ...           6090
# 87                                          Konversation           2490
# 103                                               German           1499
# ...                                                  ...            ...
# 38971  Relaxed German Conversation Practice for All L...           1400
# 38980  Alemán a través de la Literatura Germana: Goet...           5000
# 38981  Cultura, Literatura y Actualidad Alemana – Con...           3000
# 38994                                     Das Kolloquium           5000
# 38998                   A1 – A2 Beginner - German Basics           3200
#
#        student_count  session_count  has_package
# 11                84            723            1
# 12                70            278            1
# 20                46            371            1
# 87               211           1368            1
# 103              582           3571            1
# ...              ...            ...          ...
# 38971              0              0            1
# 38980              0              0            1
# 38981              0              0            1
# 38994              0              0            1
# 38998              0              0            1
#
# [1903 rows x 8 columns]

# %%
def language_is_tutor(language, tutor):        
    df_tutor_pro = is_tutor(tutor)
    df_language = pro_course_language(language)
    df_merged = pd.merge(df_tutor_pro, df_language, left_on='user_id', right_on='teacher_id', how='inner')
    # df_merged = df_merged[['user_id', 'trial_session_count', 'trial_price', 'student_count', 'session_count', 'has_package', 'session_price']]
    df_merged = df_merged[['title', 'trial_session_count', 'trial_price', 'student_count', 'session_count', 'has_package', 'session_price']]
    # df_merged = df_merged[['trial_price', 'session_price']]
    return df_merged

language_is_tutor('french', True)
# Out:
#                                                   title  trial_session_count  \
# 0                                              Français                    0
# 1                                     Informal Tutoring                  296
# 2                                       Français pour 2                  296
# 3     French conversational practice 10 lessons package                  182
# 4          Preparing DELF/DALF exam from level A2 to C2                  182
# ...                                                 ...                  ...
# 1926              Conversation décontractée et pratique                    0
# 1927  French for Beginners – Greetings and Self-Intr...                    0
# 1928  Professional French Coaching | Personalized Le...                    0
# 1929                French Beginner A1 to C2 proficient                    3
# 1930             French Conversation & Exam Preparation                    0
#
#       trial_price  student_count  session_count  has_package  session_price
# 0            1000              0              0            1           3000
# 1            1500            435           5178            1           2000
# 2            1500             16            238            1           2500
# 3             800            421           2738            1           1600
# 4             800             31            143            1           1800
# ...           ...            ...            ...          ...            ...
# 1926          500              4              7            1           1000
# 1927          500              0              0            1            700
# 1928         2500              0              0            1           5000
# 1929         1000              0              0            0           2000
# 1930          500              0              0            1           1200
#
# [1931 rows x 7 columns]

# %% [markdown]
# AI to categorize

# %%
# df_pro_course_category = df_pro_course.copy()
language = 'korean'
# df_pro_course_category = language_is_tutor(language, True)
df_pro_course_category = pro_course_language(language)
df_pro_course_category
# Out:
#            id  teacher_id language  \
# 52      14683      815733   korean
# 78      18937      815733   korean
# 159     24541      961354   korean
# 184     25483      948628   korean
# 185     25484      948628   korean
# ...       ...         ...      ...
# 38921  290552    15671315   korean
# 38951  290601    31925455   korean
# 39012  290708    21758263   korean
# 39026  290771     8324419   korean
# 39032  290788    29325526   korean
#
#                                                    title  session_price  \
# 52     Korean Conversation Practice – Speak Mostly in...           3000
# 78      General Korean Class – From A to Z, For Everyone           3200
# 159                                    Informal Tutoring           1700
# 184                              Level 1 (A1) - 22 units           2800
# 185                              Level 2 (A2) - 18 units           2800
# ...                                                  ...            ...
# 38921   [Daily Habit] 60/30-Min Korean Routine Challenge           2400
# 38951  Real Korean Conversation with K-Culture (Inter...           1800
# 39012  👩‍🎓Korean News Conversation - Korea's industry...           1500
# 39026                               For Current Students           4000
# 39032                             For Long-term Students           1300
#
#        student_count  session_count  has_package
# 52                74            538            1
# 78               322           2045            1
# 159              600          13361            1
# 184              340           3803            1
# 185               90           1522            1
# ...              ...            ...          ...
# 38921              0              0            1
# 38951              0              0            1
# 39012              0              0            1
# 39026              0              0            1
# 39032              0              0            1
#
# [1538 rows x 8 columns]

# %%
# df_pro_course_category = df_pro_course_category.iloc[0:10]
# df_pro_course_category
# Out:
#      id  teacher_id   language  \
# 0   375      436016    english
# 1   555      436016    chinese
# 2   946      502096    serbian
# 3  3190      436016    chinese
# 4  4042      463477    english
# 5  5620      499227  bulgarian
# 6  5779      502096    english
# 7  6470      517538    spanish
# 8  7313      535501    spanish
# 9  8425      538395   japanese
#
#                                                title  session_price  \
# 0                            English courses新概念英语（1）           1400
# 1                            Young Learners' Chinese           1600
# 2  Serbian for all levels! 100% target language l...           2300
# 3               One-on-One Customized Chinese lesson           1500
# 4                       One-on-One tutoring: English           3200
# 5  Bulgarian (levels A1, A2, B1, B2)   / A 10% di...           3400
# 6                       One-on-One tutoring: English           2300
# 7  One to one tutoring: Let's learn Spanish toget...           2200
# 8                         Spanish lessons One-on-One           3100
# 9      COMMUNICATIVE JAPANESE（Conversation practice)           1700
#
#    student_count  session_count  has_package
# 0             15            106            0
# 1              5             37            1
# 2             80           1113            1
# 3             73           1391            1
# 4             95           1504            1
# 5            167           3872            1
# 6             84            876            1
# 7            686           7136            1
# 8             87           1159            1
# 9            215           3205            1

# %%
def categorize(text):
    prompt = f"""
        This is a title of a language tutoring course on italki.com. Look at the title and categorize it as one of the following categories.
        '1: Language Essentials, 2: Business, 3: Conversation or 4: Test Preparation'. Only classify and respond with the index of one of the four categories and do not give extra input.
        The title may be in languages other than English. However, only categorize them according to the options given (in English). To elaborate on the categories, 'Language Essentials' is for the fundamentals of language learning.
        'Business' refers to language use in a professional context. 'Conversation' is purely for general conversation practice. 'Test preparation' is for students
        who want to pass language accreditation exams:
        \n{text}.
        """
    resp = client.chat.completions.create(
        
        model="gpt-4.1-mini",
        messages=[{"role": "user", "content": prompt}]
    )
    return resp.choices[0].message.content

# %%
df_pro_course_category["category"] = df_pro_course_category["title"].progress_apply(categorize)
df_pro_course_category
# Out:
# 100%|██████████| 1538/1538 [16:30<00:00,  1.55it/s]
#            id  teacher_id language  \
# 52      14683      815733   korean
# 78      18937      815733   korean
# 159     24541      961354   korean
# 184     25483      948628   korean
# 185     25484      948628   korean
# ...       ...         ...      ...
# 38921  290552    15671315   korean
# 38951  290601    31925455   korean
# 39012  290708    21758263   korean
# 39026  290771     8324419   korean
# 39032  290788    29325526   korean
#
#                                                    title  session_price  \
# 52     Korean Conversation Practice – Speak Mostly in...           3000
# 78      General Korean Class – From A to Z, For Everyone           3200
# 159                                    Informal Tutoring           1700
# 184                              Level 1 (A1) - 22 units           2800
# 185                              Level 2 (A2) - 18 units           2800
# ...                                                  ...            ...
# 38921   [Daily Habit] 60/30-Min Korean Routine Challenge           2400
# 38951  Real Korean Conversation with K-Culture (Inter...           1800
# 39012  👩‍🎓Korean News Conversation - Korea's industry...           1500
# 39026                               For Current Students           4000
# 39032                             For Long-term Students           1300
#
#        student_count  session_count  has_package category
# 52                74            538            1        3
# 78               322           2045            1        1
# 159              600          13361            1        3
# 184              340           3803            1        1
# 185               90           1522            1        1
# ...              ...            ...          ...      ...
# 38921              0              0            1        3
# 38951              0              0            1        3
# 39012              0              0            1        3
# 39026              0              0            1        3
# 39032              0              0            1        3
#
# [1538 rows x 9 columns]

# %%
df_pro_course_category
# Out:
#            id  teacher_id language  \
# 52      14683      815733   korean
# 78      18937      815733   korean
# 159     24541      961354   korean
# 184     25483      948628   korean
# 185     25484      948628   korean
# ...       ...         ...      ...
# 38921  290552    15671315   korean
# 38951  290601    31925455   korean
# 39012  290708    21758263   korean
# 39026  290771     8324419   korean
# 39032  290788    29325526   korean
#
#                                                    title  session_price  \
# 52     Korean Conversation Practice – Speak Mostly in...           3000
# 78      General Korean Class – From A to Z, For Everyone           3200
# 159                                    Informal Tutoring           1700
# 184                              Level 1 (A1) - 22 units           2800
# 185                              Level 2 (A2) - 18 units           2800
# ...                                                  ...            ...
# 38921   [Daily Habit] 60/30-Min Korean Routine Challenge           2400
# 38951  Real Korean Conversation with K-Culture (Inter...           1800
# 39012  👩‍🎓Korean News Conversation - Korea's industry...           1500
# 39026                               For Current Students           4000
# 39032                             For Long-term Students           1300
#
#        student_count  session_count  has_package category
# 52                74            538            1        3
# 78               322           2045            1        1
# 159              600          13361            1        3
# 184              340           3803            1        1
# 185               90           1522            1        1
# ...              ...            ...          ...      ...
# 38921              0              0            1        3
# 38951              0              0            1        3
# 39012              0              0            1        3
# 39026              0              0            1        3
# 39032              0              0            1        3
#
# [1538 rows x 9 columns]

# %%
pro_course_category = df_pro_course_category.to_dict(orient='records')

with open(f'./pro_course_category_korean.json', 'w') as file:
        json.dump(pro_course_category, file, indent=4)

# %% [markdown]
# The courses that have less than 10 sessions or 10 trial sessions should be removed\
# Since their progress has not yet stabilized, this should not be included in the training and test data.

# %%
with open('./pro_course_category_korean.json', 'r') as file:
    pro_course_korean = json.load(file)

df_pro_course_korean = pd.DataFrame(pro_course_korean)

# %%
df_pro_course_korean_encode = pd.get_dummies(df_pro_course_korean, columns=['category'], dtype=int)
df_pro_course_korean_encode
# Out:
#           id  teacher_id language  \
# 0      14683      815733   korean
# 1      18937      815733   korean
# 2      24541      961354   korean
# 3      25483      948628   korean
# 4      25484      948628   korean
# ...      ...         ...      ...
# 1533  290552    15671315   korean
# 1534  290601    31925455   korean
# 1535  290708    21758263   korean
# 1536  290771     8324419   korean
# 1537  290788    29325526   korean
#
#                                                   title  session_price  \
# 0     Korean Conversation Practice – Speak Mostly in...           3000
# 1      General Korean Class – From A to Z, For Everyone           3200
# 2                                     Informal Tutoring           1700
# 3                               Level 1 (A1) - 22 units           2800
# 4                               Level 2 (A2) - 18 units           2800
# ...                                                 ...            ...
# 1533   [Daily Habit] 60/30-Min Korean Routine Challenge           2400
# 1534  Real Korean Conversation with K-Culture (Inter...           1800
# 1535  👩‍🎓Korean News Conversation - Korea's industry...           1500
# 1536                               For Current Students           4000
# 1537                             For Long-term Students           1300
#
#       student_count  session_count  has_package  category_1  category_2  \
# 0                74            538            1           0           0
# 1               322           2045            1           1           0
# 2               600          13361            1           0           0
# 3               340           3803            1           1           0
# 4                90           1522            1           1           0
# ...             ...            ...          ...         ...         ...
# 1533              0              0            1           0           0
# 1534              0              0            1           0           0
# 1535              0              0            1           0           0
# 1536              0              0            1           0           0
# 1537              0              0            1           0           0
#
#       category_3  category_4
# 0              1           0
# 1              0           0
# 2              1           0
# 3              0           0
# 4              0           0
# ...          ...         ...
# 1533           1           0
# 1534           1           0
# 1535           1           0
# 1536           1           0
# 1537           1           0
#
# [1538 rows x 12 columns]

# %%
df_pro_course_korean_encode
# Out:
#           id  teacher_id language  \
# 0      14683      815733   korean
# 1      18937      815733   korean
# 2      24541      961354   korean
# 3      25483      948628   korean
# 4      25484      948628   korean
# ...      ...         ...      ...
# 1533  290552    15671315   korean
# 1534  290601    31925455   korean
# 1535  290708    21758263   korean
# 1536  290771     8324419   korean
# 1537  290788    29325526   korean
#
#                                                   title  session_price  \
# 0     Korean Conversation Practice – Speak Mostly in...           3000
# 1      General Korean Class – From A to Z, For Everyone           3200
# 2                                     Informal Tutoring           1700
# 3                               Level 1 (A1) - 22 units           2800
# 4                               Level 2 (A2) - 18 units           2800
# ...                                                 ...            ...
# 1533   [Daily Habit] 60/30-Min Korean Routine Challenge           2400
# 1534  Real Korean Conversation with K-Culture (Inter...           1800
# 1535  👩‍🎓Korean News Conversation - Korea's industry...           1500
# 1536                               For Current Students           4000
# 1537                             For Long-term Students           1300
#
#       student_count  session_count  has_package  category_1  category_2  \
# 0                74            538            1           0           0
# 1               322           2045            1           1           0
# 2               600          13361            1           0           0
# 3               340           3803            1           1           0
# 4                90           1522            1           1           0
# ...             ...            ...          ...         ...         ...
# 1533              0              0            1           0           0
# 1534              0              0            1           0           0
# 1535              0              0            1           0           0
# 1536              0              0            1           0           0
# 1537              0              0            1           0           0
#
#       category_3  category_4
# 0              1           0
# 1              0           0
# 2              1           0
# 3              0           0
# 4              0           0
# ...          ...         ...
# 1533           1           0
# 1534           1           0
# 1535           1           0
# 1536           1           0
# 1537           1           0
#
# [1538 rows x 12 columns]

# %%
def merge_trial_price(df_pro_course):        
    df_merged = pd.merge(df_user_course_info, df_pro_course, left_on='user_id', right_on='teacher_id', how='inner')
    # df_merged = df_merged[['user_id', 'trial_session_count', 'trial_price', 'student_count', 'session_count', 'has_package', 'session_price']]
    df_merged = df_merged[['title', 'trial_session_count', 'trial_price', 'student_count', 'session_count', 'has_package', 'category_1', 'category_2', 'category_3', 'category_4','session_price']]
    # df_merged = df_merged[['trial_price', 'session_price']]
    return df_merged

# language_is_tutor('french', True)

# %%
# # df_model = language_is_tutor('korean', True)
# df_model = df_model[(df_model['session_count'] > 15) & (df_model['trial_session_count'] > 15)]
# df_model
# Out:
#                                                  title  trial_session_count  \
# 5    Korean Conversation Practice – Speak Mostly in...                  345
# 6     General Korean Class – From A to Z, For Everyone                  345
# 8                                Formal Korean Lessons                  157
# 9                         Korean Conversation Practice                  157
# 11                                   Informal Tutoring                  125
# ..                                                 ...                  ...
# 565   Survival Korean: Essential Phrases for Travelers                   20
# 583             🌈 Beginner Korean (Start from Hangul!)                   17
# 587                         ✈️ Free-Topic Conversation                   17
# 627  🥇Structured Korean for Real-Life Communication...                   22
# 641    한국어 회화 및 문화 | 일상생활, 케이팝, 드라마 주제 | 편안하지만 체계적인 수업                   20
#
#      trial_price  student_count  session_count  has_package  session_price
# 5           1500             74            538            1           3000
# 6           1500            322           2045            1           3200
# 8           1400             30            225            1           2600
# 9           1400              6             26            1           2100
# 11          1000            290           8076            1           1500
# ..           ...            ...            ...          ...            ...
# 565         1000              4             23            1           3000
# 583          800              6             35            1           1600
# 587          800              4             32            1           1600
# 627          900             15            107            1           2000
# 641          500             52            264            1           1000
#
# [154 rows x 7 columns]

# %% [markdown]
# Generate Categories

# %%
df_merge = merge_trial_price(df_pro_course_korean_encode)
df_merge
# cor = df_merge[['trial_session_count', 'trial_price', 'student_count', 'session_count', 'has_package', 'session_price']].corr()

# #plot correlation heatmapn
# sns.heatmap(cor, cmap="YlGnBu", annot=True)
# Out:
#                                                   title  trial_session_count  \
# 0     ★Trial Lesson On Sale! for 55/40/25 minutes (お...                    0
# 1                                      📗Listen & Repeat                    0
# 2     📘Conversation（Q&A）with Feedback / 質問に答える会話授業(フ...                    0
# 3     ★Conversation (No Feedback after the lesson) /...                    0
# 4                 📕Relay Story (Writing) / リレーストーリ (作文)                    0
# ...                                                 ...                  ...
# 1533                                          기본 한국어 교실                    0
# 1534  ✨ 3,000h+ Coach! Speak Like a Native: Accurate...                    0
# 1535  Fun & Natural Korean Lessons with a Musician T...                    0
# 1536                      Beginner & Elementary Lessons                    0
# 1537  Intermediate Lessons - Speaking & Conversation...                    0
#
#       trial_price  student_count  session_count  has_package  category_1  \
# 0             750            112            456            0           0
# 1             750             64            817            1           1
# 2             750             55            687            1           0
# 3             750              4             20            1           0
# 4             750              0              0            1           0
# ...           ...            ...            ...          ...         ...
# 1533          500              0              0            1           1
# 1534          500              0              0            1           0
# 1535          500              1              2            1           0
# 1536         1000              0              0            1           1
# 1537         1000              0              0            1           0
#
#       category_2  category_3  category_4  session_price
# 0              0           1           0           1500
# 1              0           0           0           2000
# 2              0           1           0           2000
# 3              0           1           0           1800
# 4              0           1           0           2000
# ...          ...         ...         ...            ...
# 1533           0           0           0           1400
# 1534           0           1           0           1500
# 1535           0           1           0           1000
# 1536           0           0           0           3200
# 1537           0           1           0           3200
#
# [1538 rows x 11 columns]

# %%
fig = px.scatter(df_merge, x="session_price", y="trial_price", trendline='ols')

# Display the interactive figure
fig.show()

# %%
features = list(df_merge.columns)
features.remove('session_price')
features.remove('title')
features
# Out:
# ['trial_session_count',
#  'trial_price',
#  'student_count',
#  'session_count',
#  'has_package',
#  'category_1',
#  'category_2',
#  'category_3',
#  'category_4']

# %%
X = df_merge[features]
y = df_merge['session_price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
regr = RandomForestRegressor(n_estimators=100, max_depth=50, random_state=42)
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=50, random_state=42)

# %%
y_pred = regr.predict(X_test)

# %%
root_mean_squared_error(y_pred, y_test)
# Out:
# 901.3262979343775

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.4002324538587835
